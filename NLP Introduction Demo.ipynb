# %% [markdown]
# ## NLP Introduction
# ### Kip Sutter
# #### Downtown Omaha Machine Learning Group
# ##### 25th Sep 2019

# %%
# needed to display the graphs
# %matplotlib inline

# %%
# import the library and download sample texts
import nltk
#nltk.download()

# %%
from nltk.book import text4
from nltk.book import text5

# %%
# examine concordances (word + context)
text4.concordance("America")
# Out:
# Displaying 25 of 25 matches:
# posed in me by the people of united America . Previous to the execution of any
# y times , that no middle course for America remained between unlimited submissi
# this dangerous crisis the people of America were not abandoned by their usual g
# ay be exposed ) which the people of America have exhibited to the admiration an
# ty toward the aboriginal nations of America , and a disposition to meliorate th
# onor and integrity of the people of America and the internal sentiment of their
# een Spain and the colonies in South America , which had commenced many years be
#  Britannic Majesty ' s dominions in America , with other differences on importa
#  generations yet to come , and that America will present to every friend of man
# route across the isthmus of Central America . It is impossible to conceive that
# thmus that connects North and South America as will protect our national intere
# ...

# %%
text4.similar("democracy")
# Out:
# people government country war congress responsibility all peace
# mankind man life which it time duty hope nation place provision
# america

# %%
text4.common_contexts(["democracy", "liberty"])
# Out:
# of_the of_and

# %%
# see where in a text certain words are found to occur
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America","American"])

# %%
from nltk.corpus import inaugural
inaugural.fileids()
yy = [fileid[:4] for fileid in inaugural.fileids()]

# %%
cfd = nltk.ConditionalFreqDist(
    (target, fileid[:4])
    for fileid in inaugural.fileids()
    for w in inaugural.words(fileid)
    for target in ['america', 'citizen','democracy']
    if w.lower().startswith(target))
cfd.plot()

# %%
# count of all tokens (including punctuation)
len(text4)
# Out:
# 147498

# %%
# number of distinct tokens
len(set(text4))
# Out:
# 9845

# %%
# the texts are just lists of strings
text4[141525:]
# Out:
# ['be',
#  'surprised',
#  'by',
#  'the',
#  'power',
#  'of',
#  'our',
#  'ideals',
#  '.',
#  'Eventually',
#  ',',
#  'the',
#  'call',
#  'of',
#  'freedom',
#  'comes',
#  'to',
#  'every',
#  'mind',
#  'and',
#  'every',
#  'soul',
#  '.',
#  'We',
#  'do',
#  'not',
#  'accept',
#  'the',
#  'existence',
#  'of',
#  'permanent',
#  'tyranny',
#  'because',
#  'we',
#  'do',
#  'not',
#  'accept',
#  'the',
#  'possibility',
#  'of',
#  'permanent',
#  'slavery',
#  '.',
#  'Liberty',
#  'will',
#  'come',
#  'to',
#  'those',
#  'who',
#  'love',
#  'it',
#  '.',
#  'Today',
#  ',',
#  'America',
#  'speaks',
#  'anew',
#  'to',
#  'the',
#  'peoples',
#  'of',
#  'the',
#  'world',
#  ':',
#  'All',
#  'who',
#  'live',
#  'in',
#  'tyranny',
#  'and',
#  'hopelessness',
#  'can',
#  'know',
#  ':',
#  'the',
#  'United',
#  'States',
#  'will',
#  'not',
#  'ignore',
#  'your',
#  'oppression',
#  ',',
#  'or',
#  'excuse',
#  'your',
#  'oppressors',
#  '.',
#  'When',
# ...

# %%
# from nltk.corpus import inaugural
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Old World; Chief Justice; Almighty God; Fellow citizens; Chief
# Magistrate; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
# build a frequency distribution
fdist1 = nltk.FreqDist(text4) 
fdist1
# Out:
# FreqDist({'the': 9350, 'of': 7019, ',': 6958, 'and': 5063, '.': 4772, 'to': 4348, 'in': 2542, 'a': 2148, 'our': 1953, 'that': 1697, ...})

# %%
fdist1.most_common(20)
# Out:
# [('the', 9350),
#  ('of', 7019),
#  (',', 6958),
#  ('and', 5063),
#  ('.', 4772),
#  ('to', 4348),
#  ('in', 2542),
#  ('a', 2148),
#  ('our', 1953),
#  ('that', 1697),
#  ('be', 1473),
#  ('is', 1423),
#  ('we', 1163),
#  ('for', 1088),
#  ('by', 1042),
#  ('it', 1020),
#  ('which', 1006),
#  ('have', 999),
#  ('not', 926),
#  ('with', 894)]

# %%
fdist1['democracy']
# Out:
# 52

# %%
fdist1.plot(20, cumulative=True)

# %%
# apply a list comprehension to get words over 15 characters
V = set(text4)
long_words = [w for w in V if len(w) > 12]
sorted(long_words)
# Out:
# ['Administration',
#  'Administrations',
#  'Commissioners',
#  'Communications',
#  'Confederation',
#  'Congressional',
#  'Constitutional',
#  'Contemplating',
#  'Establishment',
#  'INVESTIGATION',
#  'Inconsiderable',
#  'Independently',
#  'Instinctively',
#  'International',
#  'Massachusetts',
#  'Mediterranean',
#  'Notwithstanding',
#  'Overwhelmingly',
#  'RESPONSIBILITIES',
#  'Reconstruction',
#  'Representative',
#  'Representatives',
#  'Revolutionary',
#  'accommodation',
#  'accommodations',
#  'accomplishing',
#  'accomplishment',
#  'accomplishments',
#  'accountability',
#  'acknowledging',
#  'acknowledgment',
#  'administering',
#  'administrated',
#  'administration',
#  'administrations',
#  'administrative',
#  'administrators',
#  'advantageously',
#  'adventurously',
#  'aggrandizement',
#  'agriculturists',
#  'anticipations',
#  'antiphilosophists',
#  'antirepublican',
#  'apprehensions',
#  'appropriately',
#  'appropriateness',
#  'appropriation',
# ...

# %%
fdist2 = nltk.FreqDist(text4)
sorted(w for w in set(text4) if len(w) > 7 and fdist2[w] > 7)
# Out:
# ['Administration',
#  'Almighty',
#  'American',
#  'Americans',
#  'Confederacy',
#  'Congress',
#  'Constitution',
#  'Declaration',
#  'Departments',
#  'European',
#  'Executive',
#  'Government',
#  'Independence',
#  'Jefferson',
#  'Legislature',
#  'Magistrate',
#  'National',
#  'President',
#  'Presidential',
#  'Providence',
#  'Republic',
#  'Revolution',
#  'Southern',
#  'Territories',
#  'Territory',
#  'Treasury',
#  'Washington',
#  'absolute',
#  'accepted',
#  'accomplish',
#  'accomplished',
#  'accordance',
#  'according',
#  'accountability',
#  'achieved',
#  'achievement',
#  'acknowledged',
#  'activities',
#  'additional',
#  'adequate',
#  'adherence',
#  'adjustment',
#  'administer',
#  'administered',
#  'administration',
#  'admitted',
#  'adoption',
#  'advanced',
#  'advancement',
#  'advantage',
#  'advantages',
#  'affecting',
#  'affection',
#  'afforded',
#  'agencies',
#  'aggression',
#  'agitation',
#  'agricultural',
#  'agriculture',
# ...

# %%
# word sequences that appear together unusually often
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; God
# bless; Old World; Chief Justice; Almighty God; Fellow citizens; Chief
# Magistrate; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %% [markdown]
# ## Regular Expressions

# %%
# regular expression library
import re
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

# %%
# match the end of a word
[w for w in wordlist if re.search('ed$', w)][0:10]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded']

# %%
# wildcard matches any single character
[w for w in wordlist if re.search('^..j..t..$', w)][0:10]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector']

# %%
# combination of caret (start of word) and sets
[w for w in wordlist if re.search('^[ghi][mno][jlk][def]$', w)]
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))

# plus symbol matches any number of times repeating
[w for w in chat_words if re.search('^m+i+n+e+$', w)]
# Out:
# ['miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'mine',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee']

# %%
wordlist
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aardvark',
#  'aardwolf',
#  'aba',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abaptiston',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abash',
#  'abashed',
#  'abashedly',
#  'abashedness',
#  'abashless',
#  'abashlessly',
#  'abashment',
#  'abasia',
#  'abasic',
#  'abask',
#  'abastardize',
#  'abatable',
#  'abate',
#  'abatement',
#  'abater',
#  'abatis',
#  'abatised',
#  'abaton',
# ...

# %%
wsj = sorted(set(nltk.corpus.treebank.words()))

# more advanced regex example
[w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)][0:10]
# Out:
# ['0.0085', '0.05', '0.1', '0.16', '0.2', '0.25', '0.28', '0.3', '0.4', '0.5']

# %%
[w for w in wsj if re.search('^[A-Z]+\$$', w)]
# Out:
# ['C$', 'US$']

# %%
[w for w in wsj if re.search('^[0-9]{4}$', w)][0:10]
# Out:
# ['1614',
#  '1637',
#  '1787',
#  '1901',
#  '1903',
#  '1917',
#  '1925',
#  '1929',
#  '1933',
#  '1934']

# %%
[w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$', w)][0:10]
# Out:
# ['10-day',
#  '10-lap',
#  '10-year',
#  '100-share',
#  '12-point',
#  '12-year',
#  '14-hour',
#  '15-day',
#  '150-point',
#  '190-point']

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$', w)][0:10]
# Out:
# ['black-and-white',
#  'bread-and-butter',
#  'father-in-law',
#  'machine-gun-toting',
#  'savings-and-loan']

# %%
[w for w in wsj if re.search('(ed|ing)$', w)][0:10]
# Out:
# ['62%-owned',
#  'Absorbed',
#  'According',
#  'Adopting',
#  'Advanced',
#  'Advancing',
#  'Alfred',
#  'Allied',
#  'Annualized',
#  'Anything']

# %%
# using "findall" to extract partial matches from words
fd = nltk.FreqDist(vs for word in wsj 
                      for vs in re.findall(r'[aeiou]{2,}', word))
fd.most_common(12)
# Out:
# [('io', 549),
#  ('ea', 476),
#  ('ie', 331),
#  ('ou', 329),
#  ('ai', 261),
#  ('ia', 253),
#  ('ee', 217),
#  ('oo', 174),
#  ('ua', 109),
#  ('au', 106),
#  ('ue', 105),
#  ('ui', 95)]

# %% [markdown]
# ## Classifying Names

# %%
# Define a feature extractor
def gender_features(word):
        return {'last_letter': word[-1]}
gender_features('Neil')
# Out:
# {'last_letter': 'l'}

# %%
# Prepare a list of examples
from nltk.corpus import names
labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
    [(name, 'female') for name in names.words('female.txt')])
import random
random.shuffle(labeled_names)

# %%
labeled_names
# Out:
# [('Kelley', 'female'),
#  ('Ryan', 'male'),
#  ('Sayers', 'male'),
#  ('Rennie', 'female'),
#  ('Jessee', 'male'),
#  ('Monika', 'female'),
#  ('Lorena', 'female'),
#  ('Darbie', 'female'),
#  ('Beryl', 'female'),
#  ('Sheelagh', 'female'),
#  ('Debbi', 'female'),
#  ('Jeremias', 'male'),
#  ('Erminia', 'female'),
#  ('Phoebe', 'female'),
#  ('Gregorio', 'male'),
#  ('Romain', 'male'),
#  ('Blondelle', 'female'),
#  ('Clarette', 'female'),
#  ('Ashley', 'male'),
#  ('Kania', 'female'),
#  ('Pauly', 'female'),
#  ('Cherie', 'female'),
#  ('Rosanne', 'female'),
#  ('Charo', 'female'),
#  ('Anthony', 'male'),
#  ('Hannie', 'female'),
#  ('Nev', 'male'),
#  ('Dorris', 'female'),
#  ('Hamilton', 'male'),
#  ('Loraine', 'female'),
#  ('Doll', 'female'),
#  ('Melania', 'female'),
#  ('Coretta', 'female'),
#  ('Gearard', 'male'),
#  ('Donn', 'male'),
#  ('Emalia', 'female'),
#  ('Jude', 'female'),
#  ('Yank', 'male'),
#  ('Willyt', 'female'),
#  ('Morgen', 'female'),
# ...

# %%
gender_features('Wendy')
# Out:
# {'last_letter': 'y'}

# %%
# Process the names data
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, train_set))
# Out:
# 0.762224610424503

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.772

# %%
classifier.classify(gender_features('Pat'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Michael'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Donna'))
# Out:
# 'female'

# %%
classifier.classify(gender_features('Wei'))
# Out:
# 'female'

# %%
classifier.classify(gender_features('Webb'))
# Out:
# 'male'

# %%
classifier.classify(gender_features('Brian'))
# Out:
# 'male'

# %%
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#              last_letter = 'a'            female : male   =     37.0 : 1.0
#              last_letter = 'k'              male : female =     31.4 : 1.0
#              last_letter = 'p'              male : female =     19.9 : 1.0
#              last_letter = 'f'              male : female =     15.3 : 1.0
#              last_letter = 'd'              male : female =      9.7 : 1.0
#              last_letter = 'v'              male : female =      9.2 : 1.0
#              last_letter = 'm'              male : female =      8.8 : 1.0
#              last_letter = 'o'              male : female =      8.8 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'w'              male : female =      5.1 : 1.0

# %% [markdown]
# the names in the training set that end in "a" are female 33 times more often than they are male, but names that end in "k" are male 32 times more often than they are female. These ratios are known as **likelihood ratios**
